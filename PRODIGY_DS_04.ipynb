# %% [markdown]
# TASK 4:SENTIMENT ANALYSIS IN SOCIAL MEDIA

# %%
import pandas as pd
import numpy as np

# %%
# !pip install twython
# !pip install nltk
# !pip install wordcloud

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: twython in c:\users\lenovo\documents\prolog\lib\site-packages (3.9.1)
# Requirement already satisfied: requests>=2.1.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from twython) (2.31.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from twython) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests>=2.1.0->twython) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests>=2.1.0->twython) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests>=2.1.0->twython) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests>=2.1.0->twython) (2024.2.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.2)
# Requirement already satisfied: nltk in c:\users\lenovo\documents\prolog\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\lenovo\documents\prolog\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\lenovo\documents\prolog\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lenovo\documents\prolog\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\lenovo\documents\prolog\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\lenovo\documents\prolog\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: wordcloud in c:\users\lenovo\documents\prolog\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\lenovo\documents\prolog\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\lenovo\documents\prolog\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\documents\prolog\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\documents\prolog\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\documents\prolog\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# !pip install transformers
# !pip install torch
# !pip install tensorflow
from nltk.sentiment import SentimentIntensityAnalyzer
from transformers import AutoTokenizer,AutoModelForSequenceClassification
from scipy.special import softmax
# Out:
# Requirement already satisfied: transformers in c:\users\lenovo\documents\prolog\lib\site-packages (4.42.3)
# Requirement already satisfied: filelock in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\documents\prolog\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\documents\prolog\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.9.0)
# Requirement already satisfied: colorama in c:\users\lenovo\documents\prolog\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: torch in c:\users\lenovo\documents\prolog\lib\site-packages (2.3.1)
# Requirement already satisfied: filelock in c:\users\lenovo\documents\prolog\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\lenovo\documents\prolog\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\lenovo\documents\prolog\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\documents\prolog\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\lenovo\documents\prolog\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\lenovo\documents\prolog\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\lenovo\documents\prolog\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lenovo\documents\prolog\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: tensorflow in c:\users\lenovo\documents\prolog\lib\site-packages (2.16.2)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\lenovo\documents\prolog\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\lenovo\documents\prolog\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\lenovo\documents\prolog\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\documents\prolog\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\documents\prolog\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\documents\prolog\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.1.0)

# %%
train_set=pd.read_csv("C:/Users/Lenovo/Downloads/twitter_training.csv",header=0,names=["TweetID","Entity","Sentiment","Content"])
valid_set=pd.read_csv("C:/Users/Lenovo/Downloads/twitter_validation (1).csv",header=0,names=["TweetID","Entity","Sentiment","Content"])

# %%
df=pd.concat([train_set,valid_set])
df
# Out:
#      TweetID               Entity   Sentiment  \
# 0       2401          Borderlands    Positive
# 1       2401          Borderlands    Positive
# 2       2401          Borderlands    Positive
# 3       2401          Borderlands    Positive
# 4       2401          Borderlands    Positive
# ..       ...                  ...         ...
# 994     4891  GrandTheftAuto(GTA)  Irrelevant
# 995     4359                CS-GO  Irrelevant
# 996     2652          Borderlands    Positive
# 997     8069            Microsoft    Positive
# 998     6960      johnson&johnson     Neutral
#
#                                                Content
# 0    I am coming to the borders and I will kill you...
# 1    im getting on borderlands and i will kill you ...
# 2    im coming on borderlands and i will murder you...
# 3    im getting on borderlands 2 and i will murder ...
# 4    im getting into borderlands and i can murder y...
# ..                                                 ...
# 994  ⭐️ Toronto is the arts and culture capital of ...
# 995  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
# 996  Today sucked so it’s time to drink wine n play...
# 997  Bought a fraction of Microsoft today. Small wins.
# 998  Johnson & Johnson to stop selling talc baby po...
#
# [75680 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# TweetID        0
# Entity         0
# Sentiment      0
# Content      686
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# TweetID      0
# Entity       0
# Sentiment    0
# Content      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2856

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      TweetID               Entity   Sentiment  \
# 0       2401          Borderlands    Positive
# 1       2401          Borderlands    Positive
# 2       2401          Borderlands    Positive
# 3       2401          Borderlands    Positive
# 4       2401          Borderlands    Positive
# ..       ...                  ...         ...
# 987     7516      LeagueOfLegends     Neutral
# 988     5708            HomeDepot    Positive
# 990     2165           CallOfDuty     Neutral
# 994     4891  GrandTheftAuto(GTA)  Irrelevant
# 995     4359                CS-GO  Irrelevant
#
#                                                Content
# 0    I am coming to the borders and I will kill you...
# 1    im getting on borderlands and i will kill you ...
# 2    im coming on borderlands and i will murder you...
# 3    im getting on borderlands 2 and i will murder ...
# 4    im getting into borderlands and i can murder y...
# ..                                                 ...
# 987  ♥️ Suikoden 2\n1️⃣ Alex Kidd in Miracle World\...
# 988  Thank you to Matching funds Home Depot RW paym...
# 990  Late night stream with the boys! Come watch so...
# 994  ⭐️ Toronto is the arts and culture capital of ...
# 995  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
#
# [72138 rows x 4 columns]

# %%
df.describe()
# Out:
#             TweetID
# count  72138.000000
# mean    6435.525521
# std     3743.594729
# min        1.000000
# 25%     3195.000000
# 50%     6432.000000
# 75%     9607.000000
# max    13200.000000

# %%
df.describe(include='object')
# Out:
#                       Entity Sentiment Content
# count                  72138     72138   72138
# unique                    32         4   69973
# top     TomClancysRainbowSix  Negative
# freq                    2349     21790     172

# %%
df['Entity'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Entity'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Entity'>

# %%
crosstab = pd.crosstab(index=df['Entity'], columns=df['Sentiment'])
plt.figure(figsize=(12, 8))
sns.heatmap(crosstab, cmap='coolwarm', annot=True, fmt='d', linewidths=.5, cbar_kws={'label': 'Count'})
plt.title('Heatmap of Entity Sentiment Distribution', fontsize=16)
plt.xlabel('Sentiment', fontsize=14)
plt.ylabel('Entity', fontsize=14)
# Out:
# Text(120.7222222222222, 0.5, 'Entity')

# %%
df2 = pd.get_dummies(df,columns=["Entity","Sentiment"], drop_first=True)
df2
# Out:
#      TweetID                                            Content  \
# 0       2401  I am coming to the borders and I will kill you...
# 1       2401  im getting on borderlands and i will kill you ...
# 2       2401  im coming on borderlands and i will murder you...
# 3       2401  im getting on borderlands 2 and i will murder ...
# 4       2401  im getting into borderlands and i can murder y...
# ..       ...                                                ...
# 987     7516  ♥️ Suikoden 2\n1️⃣ Alex Kidd in Miracle World\...
# 988     5708  Thank you to Matching funds Home Depot RW paym...
# 990     2165  Late night stream with the boys! Come watch so...
# 994     4891  ⭐️ Toronto is the arts and culture capital of ...
# 995     4359  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
#
#      Entity_ApexLegends  Entity_AssassinsCreed  Entity_Battlefield  \
# 0                 False                  False               False
# 1                 False                  False               False
# 2                 False                  False               False
# 3                 False                  False               False
# 4                 False                  False               False
# ..                  ...                    ...                 ...
# 987               False                  False               False
# 988               False                  False               False
# 990               False                  False               False
# 994               False                  False               False
# 995               False                  False               False
#
#      Entity_Borderlands  Entity_CS-GO  Entity_CallOfDuty  \
# 0                  True         False              False
# 1                  True         False              False
# 2                  True         False              False
# 3                  True         False              False
# 4                  True         False              False
# ..                  ...           ...                ...
# 987               False         False              False
# 988               False         False              False
# 990               False         False               True
# 994               False         False              False
# 995               False          True              False
#
#      Entity_CallOfDutyBlackopsColdWar  Entity_Cyberpunk2077  ...  \
# 0                               False                 False  ...
# 1                               False                 False  ...
# 2                               False                 False  ...
# 3                               False                 False  ...
# 4                               False                 False  ...
# ..                                ...                   ...  ...
# 987                             False                 False  ...
# 988                             False                 False  ...
# 990                             False                 False  ...
# 994                             False                 False  ...
# 995                             False                 False  ...
#
#      Entity_RedDeadRedemption(RDR)  Entity_TomClancysGhostRecon  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# ..                             ...                          ...
# 987                          False                        False
# 988                          False                        False
# 990                          False                        False
# 994                          False                        False
# 995                          False                        False
#
#      Entity_TomClancysRainbowSix  Entity_Verizon  Entity_WorldOfCraft  \
# 0                          False           False                False
# 1                          False           False                False
# 2                          False           False                False
# 3                          False           False                False
# 4                          False           False                False
# ..                           ...             ...                  ...
# 987                        False           False                False
# 988                        False           False                False
# 990                        False           False                False
# 994                        False           False                False
# 995                        False           False                False
#
#      Entity_Xbox(Xseries)  Entity_johnson&johnson  Sentiment_Negative  \
# 0                   False                   False               False
# 1                   False                   False               False
# 2                   False                   False               False
# 3                   False                   False               False
# 4                   False                   False               False
# ..                    ...                     ...                 ...
# 987                 False                   False               False
# 988                 False                   False               False
# 990                 False                   False               False
# 994                 False                   False               False
# 995                 False                   False               False
#
#      Sentiment_Neutral  Sentiment_Positive
# 0                False                True
# 1                False                True
# 2                False                True
# 3                False                True
# 4                False                True
# ..                 ...                 ...
# 987               True               False
# 988              False                True
# 990               True               False
# 994              False               False
# 995              False               False
#
# [72138 rows x 36 columns]

# %%
corr = df2.drop(columns=["TweetID","Content"]).corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
entity_list = ' '.join(crosstab.index)
plt.axis('off')
wc = WordCloud(width=2000, height=1000).generate(entity_list)
plt.title("Entity Word Cloud")
plt.imshow(wc, interpolation='bilinear')

# %%
corpus = ' '.join(df['Content'])
plt.axis('off')
plt.title("Corpus Word Cloud")
wc2 = WordCloud(width=2000, height=1000).generate(corpus)
plt.imshow(wc2, interpolation='bilinear')

# %%
df['Content'] = df['Content'].astype(str)

# %%
import random
random.seed(42)
sampled_df = df.sample(n=2000, random_state=random.randint(0, 10000))
sampled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 71653 to 31326
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TweetID    2000 non-null   int64
#  1   Entity     2000 non-null   object
#  2   Sentiment  2000 non-null   object
#  3   Content    2000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 78.1+ KB

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def polarity_scores_roberta(ex):
    encoded_text = tokenizer(ex, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg': scores[0],
        'roberta_neu': scores[1],
        'roberta_pos': scores[2]
    }
    return scores_dict

# %%
res = {}
sampled_df.info()
for i,row in tqdm(sampled_df.iterrows(), total=len(sampled_df)):
    try: 
        text = row['Content']
        id = row['TweetID']
        roberta_results = polarity_scores_roberta(text)
        res[id] = {**roberta_results}
    except RuntimeError:
        print(f"Broke for id {id}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 71653 to 31326
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TweetID    2000 non-null   int64
#  1   Entity     2000 non-null   object
#  2   Sentiment  2000 non-null   object
#  3   Content    2000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 78.1+ KB
#   0%|          | 0/2000 [00:01<?, ?it/s]

# %%
results_df = pd.DataFrame(res).transpose()
results_df = results_df.reset_index().rename(columns={'index':'TweetID'})
results_df = results_df.merge(sampled_df)

# %%
 results_df['Roberta_Sentiment'] = results_df[['roberta_neg', 'roberta_neu', 'roberta_pos']].apply(
    lambda x: 'Positive' if x['roberta_pos'] > max(x['roberta_neg'], x['roberta_neu']) 
              else 'Negative' if x['roberta_neg'] > max(x['roberta_pos'], x['roberta_neu']) 
              else 'Neutral', axis=1)
results_df.head()
results_df["Roberta_Sentiment"].value_counts(), results_df["Sentiment"].value_counts()
# Out:
# (Roberta_Sentiment
#  Negative    886
#  Positive    696
#  Neutral     418
#  Name: count, dtype: int64,
#  Sentiment
#  Negative      625
#  Positive      534
#  Neutral       502
#  Irrelevant    339
#  Name: count, dtype: int64)

# %%
fig, axs = plt.subplots(1,2, figsize=(21,7))
sns.countplot(data=results_df, x='Roberta_Sentiment', ax=axs[0])
sns.countplot(data=results_df, x='Sentiment',ax=axs[1])
axs[0].set_title("Roberta Model's Sentiment")
axs[1].set_title("Dataset's Sentiment Received")
plt.show()

# %%
plt.figure(figsize=(15,8))
sentiment_by_topic = results_df.groupby(['Entity','Roberta_Sentiment']).size().unstack(fill_value=0)
sentiment_by_topic.plot(kind='bar', stacked=True)
plt.title('Roberta Model Sentiment by Entity')
plt.xlabel('Topic')
plt.ylabel('Count')
plt.show()
